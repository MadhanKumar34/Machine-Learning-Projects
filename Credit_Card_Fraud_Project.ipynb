# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
ccdata=pd.read_csv('creditcard.csv')

# %%
ccdata.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
ccdata.shape
# Out:
# (25838, 31)

# %%
ccdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25838 entries, 0 to 25837
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    25838 non-null  int64
#  1   V1      25838 non-null  float64
#  2   V2      25838 non-null  float64
#  3   V3      25837 non-null  float64
#  4   V4      25837 non-null  float64
#  5   V5      25837 non-null  float64
#  6   V6      25837 non-null  float64
#  7   V7      25837 non-null  float64
#  8   V8      25837 non-null  float64
#  9   V9      25837 non-null  float64
#  10  V10     25837 non-null  float64
#  11  V11     25837 non-null  float64
#  12  V12     25837 non-null  float64
#  13  V13     25837 non-null  float64
#  14  V14     25837 non-null  float64
#  15  V15     25837 non-null  float64
#  16  V16     25837 non-null  float64
#  17  V17     25837 non-null  float64
#  18  V18     25837 non-null  float64
#  19  V19     25837 non-null  float64
# ...

# %%
ccdata.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
ccdata['Class'].value_counts()
# Out:
# 0.0    25749
# 1.0       88
# Name: Class, dtype: int64

# %%
normal=ccdata[ccdata.Class==0]
fraud=ccdata[ccdata.Class==1]

# %%
normal.shape,fraud.shape
# Out:
# ((25749, 31), (88, 31))

# %%
normal_sample=normal.sample(n=88)

# %%
new_set=pd.concat([normal_sample,fraud],axis=0)

# %%
new_set.shape
# Out:
# (176, 31)

# %%
X=new_set.drop('Class',axis=1)
Y=new_set['Class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train,X_test,Y_train,Y_test
# Out:
# (        Time         V1         V2         V3         V4         V5        V6  \
#  25216  33533  -0.009776   0.298190   1.711482  -0.248109  -0.813896 -0.560312
#  17297  28610   1.254435   0.432365  -0.232487   0.916317   0.246007 -0.682826
#  18476  29535   1.025173  -0.272328   0.864368   1.433482  -0.711213  0.213390
#  15166  26523 -18.474868  11.586381 -21.402917   6.038515 -14.451158 -4.146524
#  12462  21855  -1.323422   1.586953   0.237704   3.274350  -0.405820  0.122332
#  ...      ...        ...        ...        ...        ...        ...       ...
#  12270  21434 -10.453889   5.399837  -8.142489   1.556225  -6.437752 -1.465877
#  11710  20011 -14.724627   7.875157 -21.872317  11.906170  -8.348734 -2.262846
#  9487   14073  -4.153014   8.204797 -15.031714  10.330100  -3.994426 -3.250013
#  15204  26556 -19.179826  11.817922 -21.919174   6.086236 -14.708845 -4.308888
#  16404  27777   0.987954  -1.294507  -0.385479  -0.758767  -0.793835 -0.323681
#
# ...

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
Y_pred=model.predict(X_test)

# %%
acc=accuracy_score(Y_test,Y_pred)
acc
# Out:
# 0.9722222222222222
